# %%
import mlflow
import pandas as pd

# %%
import mlflow
from pathlib import Path

# Set the MLflow tracking URI

# Use an absolute path
mlflow.set_tracking_uri('file:///c:/Users/polin/OneDrive/Documents/GitHub/Supervised-ML-BankPrediction-Classification/mlruns')

# %%
model_name = "logistic_regression_pipeline"
model_version = "2"

model = mlflow.pyfunc.load_model(f"models:/{model_name}/{model_version}")
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: logistic_regression_pipeline
#   flavor: mlflow.sklearn
#   run_id: 5e74c79f77d34642969088afa0a05232

# %%
root_path = 'C:\\Users\\polin\\OneDrive\\Documents\\GitHub\\Supervised-ML-BankPrediction-Classification\\data\\'
df = pd.read_csv(root_path + 'bank_marketing_campaign.csv')
df.head(2)
# Out:
#    age        job  marital    education  default housing loan  pdays  \
# 0   56  housemaid  married     basic.4y       no      no   no    999
# 1   57   services  married  high.school  unknown      no   no    999
#
#    previous     poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0         0  nonexistent           1.1          93.994          -36.4
# 1         0  nonexistent           1.1          93.994          -36.4
#
#    euribor3m  nr.employed  y
# 0      4.857       5191.0  0
# 1      4.857       5191.0  0

# %%
input_data = df.loc[df["y"] == 1].sample(10)
input_data
# Out:
#        age           job   marital            education default housing loan  \
# 39736   31    technician  divorced    university.degree      no      no   no
# 2104    41        admin.    single              unknown      no     yes  yes
# 27737   41      services   married          high.school      no      no   no
# 39772   56    unemployed   married             basic.9y      no      no   no
# 27962   59   blue-collar   married             basic.4y      no      no   no
# 33425   36        admin.    single             basic.9y      no     yes   no
# 40595   32      services    single    university.degree      no     yes   no
# 30217   30  entrepreneur    single    university.degree      no      no   no
# 19748   31    technician    single  professional.course      no      no   no
# 40773   34    technician    single    university.degree      no      no  yes
#
#        pdays  previous     poutcome  emp.var.rate  cons.price.idx  \
# ...

# %%
model.predict(input_data.drop("y", axis=1))
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 1, 0, 1], dtype=int64)
